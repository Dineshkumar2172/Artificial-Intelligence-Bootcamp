# %% [markdown]
# ## Implementing simple chatbot using Langgraph

# %%
from typing_extensions import TypedDict

from langgraph.graph import START, END, StateGraph

# reducers
from typing import Annotated
from langgraph.graph.message import add_messages

# %%
# it's gonna append messages one after another
# every new messages will get append onto the list one after another
# in case of chatbot, there's gonna be human messages and then AI messages
#
# format: {messages: [HumanMessage, AIMessage, HumanMessage, etc...]}

class State(TypedDict):
    messages: Annotated[list, add_messages]

# %%
grapg =
