# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

model = ChatOpenAI(
    model=os.getenv("CHAT_MODEL"),
    base_url=os.getenv("IQ_BASE_URL")
)

# %%
from dataclasses import dataclass

@dataclass
class ContactInfo:
    """Contact information for a person"""
    name: str # The name of the person
    email: str # The email address of the person
    phone: str # The phone number of the person

model_with_structure = model.with_structured_output(ContactInfo)
model_with_structure.invoke("Give me contact information of some random person from internet")
# Out:
# {'name': 'John Doe', 'email': 'john.doe@example.com', 'phone': '555-123-4567'}
