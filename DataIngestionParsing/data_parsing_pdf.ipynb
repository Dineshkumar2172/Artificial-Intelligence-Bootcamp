# %% [markdown]
# # **Load PDF Files**

# %%
from langchain.document_loaders import (
    PyPDFLoader,
    PyMuPDFLoader,
    UnstructuredPDFLoader
)

# %%
## Method 1 - PypdfLoader
print("Using PyPDFLoader", end="\n\n")

try:
    pypdf_loader = PyPDFLoader("data/pdf/attention.pdf")
    pypdf_docs = pypdf_loader.load()
    print(pypdf_docs)

    print(f" Loaded {len(pypdf_docs)} pages")
    print(f" Page 1 Content : {pypdf_docs[0].page_content[:100]}...")
    print(f" Metadata : {pypdf_docs[0].metadata}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Using PyPDFLoader
#
# ...

# %%
## Method 2 - PyMuPDFLoader (Fast and Accurate)
print("Using PyPDFLoader", end="\n\n")

try:
    pymupdf_loader = PyMuPDFLoader("data/pdf/attention.pdf")
    pymupdf_docs = pymupdf_loader.load()
    print(pymupdf_docs)

    print(f" Loaded {len(pymupdf_docs)} pages")
    print(f" Page 1 Content : {pymupdf_docs[0].page_content[:100]}...")
    print(f" Metadata : {pymupdf_docs[0].metadata}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Using PyPDFLoader
#
# ...

# %%
## Method 3 - UnstructuredPDFLoader (Fast and Accurate)
print("Using PyPDFLoader", end="\n\n")

try:
    pymupdf_loader = PyMuPDFLoader("data/pdf/attention.pdf")
    pymupdf_docs = pymupdf_loader.load()
    print(pymupdf_docs)
    
    print(f" Loaded {len(pymupdf_docs)} pages")
    print(f" Page 1 Content : {pymupdf_docs[0].page_content[:100]}...")
    print(f" Metadata : {pymupdf_docs[0].metadata}")
except Exception as e:
    print(f"Error: {e}")
